# %% [markdown]
# <a href="https://colab.research.google.com/github/nhatnhat2210/Colab/blob/main/Lab_3_20130350_LeMinhNhat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/Colab'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/Colab

# %%
#import
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics 
from sklearn import preprocessing

# %% [markdown]
# **Deadline: 23:59, 04/03/2023**

# %% [markdown]
# # Task 1.
# The main aim of this task is to get familiar with the tasks of preprocessing data using Scikit-learn – a Python-based Machine Learning framework and Linear Regression.

# %% [markdown]
# For given 2 datasets (preprocessing_weather.csv, preprocessing_salary_dummy.csv),
# *   Identify issues with these datasets
# *   Then, apply preprocessing techniques to the datasets

# %% [markdown]
# #Task 1.1. Dataset preprocessing_weather.csv

# %% [markdown]
# **Issues**:
#
#
# 1.   List item
# 2.   List item
# 3.   List item
# 4.   List item
# ....

# %% [markdown]
# **Preprocessing dataset**:

# %%
#code
dataset = pd.read_csv("preprocessing_weather.csv")
dataset
# Out:
#     id   outlook temperature humidity  windy play
# 0    1     sunny          85       85  False   no
# 1    2     sunny          80       90   True   no
# 2    3  overcast          83       86  False  yes
# 3    4     rainy       NaN         96  False  yes
# 4    5     rainy          68       80  False  yes
# 5    6     rainy          65       70   True   no
# 6    7  overcast          64       65   True  yes
# 7    8     sunny          72       95  False   no
# 8    9     sunny          69    NaN    False  yes
# 9   10     rainy          75       80  False  yes
# 10  11     sunny          75       70   True  yes
# 11  12  overcast          72       90   True  yes
# 12  13  overcast          81       75  False  yes
# 13  14     rainy          71       91   True   no

# %%
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
dataset[['temperature', 'humidity']] = imp.fit_transform(dataset[['temperature', 'humidity']])
dataset
# Out:
#     id   outlook  temperature   humidity  windy play
# 0    1     sunny    85.000000  85.000000  False   no
# 1    2     sunny    80.000000  90.000000   True   no
# 2    3  overcast    83.000000  86.000000  False  yes
# 3    4     rainy    73.846154  96.000000  False  yes
# 4    5     rainy    68.000000  80.000000  False  yes
# 5    6     rainy    65.000000  70.000000   True   no
# 6    7  overcast    64.000000  65.000000   True  yes
# 7    8     sunny    72.000000  95.000000  False   no
# 8    9     sunny    69.000000  82.538462  False  yes
# 9   10     rainy    75.000000  80.000000  False  yes
# 10  11     sunny    75.000000  70.000000   True  yes
# 11  12  overcast    72.000000  90.000000   True  yes
# 12  13  overcast    81.000000  75.000000  False  yes
# 13  14     rainy    71.000000  91.000000   True   no

# %% [markdown]
# #Task 1.2. Dataset preprocessing_salary_dummy.csv

# %% [markdown]
# **Issues**:
#
#
# 1.   List item
# 2.   List item
# 3.   List item
# 4.   List item
# ....

# %% [markdown]
# **Preprocessing dataset**:

# %%
#code
dataset_p = pd.read_csv("preprocessing_salary_dummy.csv")
dataset_p
# Out:
#    No    Country   Age     Salary  Purchased
# 0   1     France  44.0     72000.0        No
# 1   2      Spain  27.0     48000.0       Yes
# 2   3    Germany  30.0     54000.0        No
# 3   4      Spain  38.0     61000.0        No
# 4   5    Germany  40.0         NaN       Yes
# 5   6     France  35.0     58000.0       Yes
# 6   7      Spain   NaN     52000.0        No
# 7   8     France  48.0     79000.0       Yes
# 8   9    Germany  50.0     83000.0        No
# 9  10     France  37.0     67000.0       Yes

# %%
from scipy.sparse import data
#code
imp = SimpleImputer(missing_values= np.nan, strategy="mean")
dataset_p[[' Age','   Salary ']] = imp.fit_transform(dataset_p[[' Age','   Salary ']])
dataset_p
# Out:
#    No    Country        Age       Salary  Purchased
# 0   1     France  44.000000  72000.000000        No
# 1   2      Spain  27.000000  48000.000000       Yes
# 2   3    Germany  30.000000  54000.000000        No
# 3   4      Spain  38.000000  61000.000000        No
# 4   5    Germany  40.000000  63777.777778       Yes
# 5   6     France  35.000000  58000.000000       Yes
# 6   7      Spain  38.777778  52000.000000        No
# 7   8     France  48.000000  79000.000000       Yes
# 8   9    Germany  50.000000  83000.000000        No
# 9  10     France  37.000000  67000.000000       Yes

# %% [markdown]
# # **Task 2**. Simple Linear Regression in Scikit-Learn
# ---
# # **Usage:**
# > **Step 1**: build a model
# ![image.png](data:image/png;base64,...)
#
# > **Step 2**: test the model
#
# *   With test set:
# `y_pred = regressor.predict(X_test)`
#
# *   With a single value ("predict" method always expects a 2D array as the format of its inputs)
# `regressor.predict([[12]])`
#
# > **Step 3**:
# *   get w0, w1 , w2, …,
# -- W0: `regressor.intercept_`
# -- w1, w2, …: `regressor.coef_`
# *   R^2 score: sum of squared r(i)
# `r(i) = y(i) - f(x(i))`: residual of ith instance
#
#
# > **Metrics**:
# *   metrics.explained_variance_score(y_test, y_pred)
# *   metrics.mean_absolute_error(y_ test, y_pred)
# *   metrics.mean_squared_error(y_ test, y_pred[, ...])
# *   metrics.mean_squared_log_error(y_ test, y_pred)
# *   metrics.median_absolute_error(y_ test, y_pred)
# *   metrics.r2_score(y_ test, y_pred[, ...])

# %% [markdown]
# ---

# %% [markdown]
# # Tasks
# The main aim of these tasks is to get familiar with Linear Regression problems. Apply LinearRegression to the following datasets. Note the error obtained and coefficients
# *   **dataset1.csv** - a synthetic dataset including 5 points (1-dimensional data) with one target
# *   **dataset2.csv** - a synthetic dataset including 1000 points (3-dimensional data) with one target variable. The variables are named x1, x2, x3, y. y is the variable to be regressed. Split the dataset into training set and test set (70% for training set and 30% for test set).

# %% [markdown]
# # Task 2.1. dataset1.csv

# %%
#code
data = pd.read_csv('dataset1.csv')
X_train = data[['x']]
Y_train = data[['y']]
print(X_train)
print(Y_train)
# Out:
#    x
# 0  1
# 1  2
# 2  4
# 3  3
# 4  5
#    y
# 0  1
# 1  3
# 2  3
# 3  2
# 4  5

# %%
#To create  Instance of Simple  Linear Regression Model
regressor = LinearRegression()

#To fit the X_train and Y_train
regressor.fit(X_train, Y_train)
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# [0.4]
# [[0.8]]

# %%
#y = 0.4 + 0.8x
y_pred = regressor.predict(X_train)
y_pred
# Out:
# array([[1.2],
#        [2. ],
#        [3.6],
#        [2.8],
#        [4.4]])

# %%
#r2
r2 = metrics.r2_score(Y_train, y_pred)
r2
# Out:
# 0.7272727272727273

# %% [markdown]
# # Task 2.2. dataset2.csv

# %%
#code
dataset2 = pd.read_csv('dataset2.csv')
dataset2
x = dataset2[['x1', 'x2', 'x3']]
y = dataset2[['y']]
X2_train, X2_test, Y2_train, Y2_test  = train_test_split(x, y, train_size=0.7, random_state=1)
X2_test
# Out:
#          x1       x2        x3
# 442  1.2023 -2.15540 -0.016177
# 286  2.2768 -0.38135 -1.296800
# 379  1.3902 -1.34650 -1.118800
# 522 -2.4820 -0.83801  1.546100
# 200 -2.3137  1.44920  0.322290
# ..      ...      ...       ...
# 347 -1.0003 -0.59847  0.586960
# 509  0.4255  0.65941 -0.867100
# 528 -1.8838  2.15970  0.436220
# 260 -1.8727 -0.77051 -0.763020
# 328  2.0946 -0.33009  1.567200
#
# [180 rows x 3 columns]

# %%
#To create  Instance of Simple  Linear Regression Model
regressor = LinearRegression()

#To fit the X_train and Y_train
regressor.fit(X2_train, Y2_train)
print(regressor.intercept_)
print(regressor.coef_)

#y = 4.00001817 + 2.99999344x1 + 3.99999127x2 + 4.99999257x3
Y2_pred = regressor.predict(X2_test)
Y2_pred
# Out:
# [4.00001817]
# [[2.99999344 3.99999127 4.99999257]]
# array([[ -1.09555578],
#        [  2.8210162 ],
#        [ -2.80937088],
#        [  0.93249028],
#        [  4.46716831],
#        [ 18.10287426],
#        [-17.89014239],
#        [  9.33475504],
#        [  4.2172295 ],
#        [ 23.10458022],
#        [  7.45103989],
#        [  8.46790232],
#        [ 18.21853963],
#        [ -4.1790449 ],
#        [  6.84075532],
#        [  2.95235554],
#        [  8.85771318],
#        [ -0.74380608],
#        [ 15.01121205],
#        [ 10.95829732],
#        [-18.12084033],
#        [ -4.44901511],
#        [ -0.8096726 ],
#        [ 22.74597955],
#        [-13.42213109],
#        [ 18.65213357],
#        [  9.02682145],
#        [ -4.48153144],
#        [ 10.20839999],
#        [ 14.95625146],
#        [  6.46187879],
#        [ 12.21761812],
#        [  0.73402813],
#        [  8.62311167],
#        [ -4.17021239],
#        [-12.78144779],
#        [ 15.66638407],
# ...

# %%
print(metrics.explained_variance_score(Y2_test, Y2_pred))
print(metrics.mean_absolute_error(Y2_test, Y2_pred))
print(metrics.mean_squared_error(Y2_test, Y2_pred))
print(metrics.median_absolute_error(Y2_test, Y2_pred))
print(metrics.r2_score(Y2_test, Y2_pred))
# Out:
# 0.9999999994118407
# 0.00016805050852401163
# 5.169591105118897e-08
# 0.00012461088137394327
# 0.999999999411653

# %% [markdown]
# # Task 2.3. Apply LinearRegression to the following dataset:
# *   Red wine quality: https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv . The dataset includes info about the chemical properties of different types of wine and how they relate to overall quality.

# %%
#code
dataset3 = pd.read_csv('Task3_winequality-red.csv', sep=';')
dataset3
x3 = dataset3[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol']]
y3 = dataset3[['quality']]
X3_train, X3_test, Y3_train, Y3_test = train_test_split(x3, y3, train_size=0.7, random_state=1)
X3_test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 75              8.8              0.41         0.64             2.2      0.093
# 1283            8.7              0.63         0.28             2.7      0.096
# 408            10.4              0.34         0.58             3.7      0.174
# 1281            7.1              0.46         0.20             1.9      0.077
# 1118            7.1              0.39         0.12             2.1      0.065
# ...             ...               ...          ...             ...        ...
# 1596            6.3              0.51         0.13             2.3      0.076
# 985             7.4              0.58         0.00             2.0      0.064
# 671             8.2              0.73         0.21             1.7      0.074
# 1379            7.5              0.57         0.02             2.6      0.077
# 1169            7.6              0.50         0.29             2.3      0.086
#
# ...

# %%
#To create  Instance of Simple  Linear Regression Model
regressor = LinearRegression()

#To fit the X_train and Y_train
regressor.fit(X3_train, Y3_train)
print(regressor.intercept_)
print(regressor.coef_)

#y = w0 + w1x1 + w2x2 + w3x3 + ...
Y3_pred = regressor.predict(X3_test)
Y3_pred
# Out:
# [36.54693744]
# [[ 4.58527906e-02 -1.17640321e+00 -2.87778222e-01  1.64922765e-02
#   -1.80636202e+00  6.07141383e-03 -3.77903394e-03 -3.26155240e+01
#   -3.75065394e-01  8.87110235e-01  2.67134606e-01]]
# array([[5.54096565],
#        [5.36989645],
#        [6.10505858],
#        [5.74193275],
#        [6.70446788],
#        [5.99284464],
#        [6.21945794],
#        [5.06042533],
#        [5.76434777],
#        [5.16110692],
#        [6.20053845],
#        [5.3581788 ],
#        [5.57545788],
#        [6.48751434],
#        [5.6342095 ],
#        [5.36206798],
#        [5.9692357 ],
#        [5.42284425],
#        [5.61642209],
#        [5.42472535],
#        [5.76425606],
#        [6.19843286],
#        [5.38347544],
#        [6.44302873],
#        [5.4465834 ],
#        [6.30871137],
#        [6.12437492],
#        [5.66115672],
#        [5.32571352],
#        [5.75947059],
#        [5.26190019],
#        [6.39964188],
#        [5.21608271],
#        [6.3101122 ],
# ...

# %%
print(metrics.explained_variance_score(Y3_test, Y3_pred))
print(metrics.mean_absolute_error(Y3_test, Y3_pred))
print(metrics.mean_squared_error(Y3_test, Y3_pred))
print(metrics.median_absolute_error(Y3_test, Y3_pred))
print(metrics.r2_score(Y3_test, Y3_pred))
# Out:
# 0.322718320445045
# 0.49692250656277537
# 0.4147279618151066
# 0.394611782721876
# 0.3186005776026659

# %% [markdown]
# # Task 2.4. Apply LinearRegression to the following dataset:
# *   Energy efficiency: https://archive.ics.uci.edu/ml/datasets/Energy+efficiency.

# %%
#code
dataset4 = pd.read_excel('Task4_ENB2012_data.xlsx')
dataset4
x4 = dataset4[['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8']]
y4 = dataset4[['Y1', 'Y2']]
X4_train, X4_test, Y4_train, Y4_test  = train_test_split(x4, y4, train_size=0.7, random_state=1)
Y4_test
# Out:
#         Y1     Y2
# 285  12.74  13.97
# 101  29.68  29.44
# 581  36.57  35.39
# 352  38.57  43.86
# 726  34.72  38.79
# ..     ...    ...
# 241  24.33  25.98
# 599  40.42  39.70
# 650  14.10  16.57
# 11   18.31  27.87
# 214  33.09  33.89
#
# [231 rows x 2 columns]

# %%
#To create  Instance of Simple  Linear Regression Model
regressor = LinearRegression()

#To fit the X_train and Y_train
regressor.fit(X4_train, Y4_train)
print(regressor.intercept_)
print(regressor.coef_)

#y1 = 80.88875028 + w1x1 + w2x2 + w3x3 + ...
#y2 = 104.37765051 +  w1x1 + w2x2 + w3x3 + ...
Y4_pred = regressor.predict(X4_test)
Y4_pred
# Out:
# [ 80.88875028 104.37765051]
# [[-6.24773307e+01 -6.08177832e-02  3.52657449e-02 -4.80417641e-02
#    4.17049559e+00  4.20223146e-02  1.99397468e+01  2.11058425e-01]
#  [-7.41167713e+01 -7.17332169e-02  2.33646665e-02 -4.75489417e-02
#    4.11598430e+00  2.10253526e-01  1.49232091e+01  5.54898306e-02]]
# array([[13.12064806, 15.33739547],
#        [27.47098304, 29.91374082],
#        [33.45290707, 34.39070357],
#        [32.50930958, 34.22990733],
#        [34.12810466, 34.76742658],
#        [15.23500767, 17.01282755],
#        [12.28606796, 14.9845997 ],
#        [28.37938926, 29.80333815],
#        [15.09745608, 17.45175389],
#        [26.31199281, 29.74858168],
#        [17.81350644, 19.00949281],
#        [30.46194505, 32.15222219],
#        [31.72515376, 33.51266686],
#        [17.26437579, 19.26353037],
#        [13.0671411 , 16.19682886],
#        [32.63537652, 34.8606679 ],
#        [27.22832298, 31.01888596],
#        [17.72851495, 19.58476355],
# ...

# %%
print(metrics.explained_variance_score(Y4_test, Y4_pred))
print(metrics.mean_absolute_error(Y4_test, Y4_pred))
print(metrics.mean_squared_error(Y4_test, Y4_pred))
print(metrics.median_absolute_error(Y4_test, Y4_pred))
print(metrics.r2_score(Y4_test, Y4_pred))
# Out:
# 0.8791002414993998
# 2.427440828693592
# 11.606084369361866
# 1.5652325170525865
# 0.8789895166048596

# %% [markdown]
# # Finally,
# Save a copy in your Github. Remember renaming the notebook.
